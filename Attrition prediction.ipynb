# %% [markdown]
# ### Program to predicts employees attrition

# %% [markdown]
# ### Understanding the data

# %%
# import the libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('./Data/WA_Fn-UseC_-HR-Employee-Attrition.csv') #load the data into Datafream

# %%
df.head() #print first 5 row  of data
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None) #to show all columns
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
plt.style.use('ggplot') #to change styling of plots ,..optional

# %%
df.shape #to find rows and columns in data
# Out:
# (1470, 35)

# %%
df.isnull().sum() #to check the empty values in column
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.info() #to find data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe() #summary for numrical data
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#summary for categorical data

categorical = [col for col in df.columns if df[col].dtype=='object'] #to get the categorical columns

# %%
categorical
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
for i in categorical:
    print(str(df[i].value_counts()))
    print('_____________________________________________________')
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# _____________________________________________________
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# _____________________________________________________
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# _____________________________________________________
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# _____________________________________________________
# Male      882
# Female    588
# Name: Gender, dtype: int64
# _____________________________________________________
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# ...

# %% [markdown]
# ### Data preparation

# %%
# drop unnecessary data 
df = df.drop(['EmployeeCount', 'Over18','EmployeeNumber','StandardHours'],axis = 1)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# ...

# %% [markdown]
# ### Data visualization

# %% [markdown]
# ### Numarical data

# %%
df['Attrition'].value_counts() # no of employees stayed and left company
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df['Attrition'].value_counts().plot(kind='bar') # visualization of no of employees stayed and left company
plt.title('Attrition')
# Out:
# Text(0.5, 1.0, 'Attrition')

# %%
fig , ax = plt.subplots(figsize=(15,8)) # Attrition by age
sns.countplot(data = df , x = 'Age' ,hue='Attrition' )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.subplots(figsize=(15,8)) # Attrition by TotalWorkingYears
sns.countplot(data = df , x = 'TotalWorkingYears' ,hue='Attrition' )
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='count'>

# %%
plt.subplots(figsize=(15,8)) # Attrition by DistanceFromHome
sns.countplot(data = df , x = 'DistanceFromHome' ,hue='Attrition' )
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='count'>

# %%
plt.subplots(figsize=(15,8)) # Attrition by YearsAtCompany
sns.countplot(data = df , x = 'YearsAtCompany' ,hue='Attrition' )
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='count'>

# %%
plt.subplots(figsize=(15,8)) # Attrition by JobLevel
sns.countplot(data = df , x = 'JobLevel' ,hue='Attrition' )
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# ### Categorical data

# %%
fig ,ax = plt.subplots(3,2 , figsize = (18,15))
# Attrition by BusinessTravel
sns.countplot(data=df , x='BusinessTravel',hue='Attrition',ax = ax[0][0]) 
# Attrition by Department
sns.countplot(data=df , x='Department',hue='Attrition',ax = ax[1][0]) 
# Attrition by EducationField
sns.countplot(data=df , x='EducationField',hue='Attrition',ax = ax[2][0]) 
# Attrition by Gender
sns.countplot(data=df , x='Gender',hue='Attrition',ax = ax[0][1])
# Attrition by OverTime
sns.countplot(data=df , x='OverTime',hue='Attrition',ax = ax[1][1])
# Attrition by Department
sns.countplot(data=df , x='Department',hue='Attrition',ax = ax[2][1])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
fig,ax = plt.subplots(2,figsize=(18,15))
#attrition by jobrols
sns.countplot(data=df,x='JobRole', hue='Attrition' ,ax=ax[0])
#attriton by MaritalStatus
sns.countplot(data=df,x='MaritalStatus', hue='Attrition' ,ax=ax[1])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# ...

# %%
#OverTime vs Department
sns.factorplot(x = 'OverTime' , col = 'Department',hue = 'Attrition',data = df , kind = 'count')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# JobInvolvement vs JobSatisfaction
sns.factorplot(x = 'JobInvolvement' , col = 'JobSatisfaction',hue = 'Attrition',data = df , kind = 'count')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
corr = df.corr(method = 'pearson')
sns.set(style="white")
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(10, 8))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ### feature engg

# %%
from sklearn.preprocessing import LabelEncoder # import Labelencoder

# %%
 # covert categorical data into numarical
for i in df.columns:
    if df[i].dtype == np.number:
        continue
    else:
        df[i] = LabelEncoder().fit_transform(df[i])
# Out:
# <ipython-input-30-83a9a4a688a8>:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[i].dtype == np.number:

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   23          1               2        624           2                 0
# 1   31          0               1        113           1                 7
# 2   19          1               2        805           1                 1
# 3   15          0               1        820           1                 2
# 4    9          0               2        312           1                 1
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0          1               1                        1       0          64
# 1          0               1                        2       1          31
# 2          1               4                        3       1          62
# 3          3               1                        3       0          26
# 4          0               3                        0       1          10
#
# ...

# %% [markdown]
# ### Model building

# %%
#splite data into feature and target matrx
feature_mtx = df.drop('Attrition',axis = 1)
target_mtx = df['Attrition']

# %%
feature_mtx.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   23               2        624           2                 0          1
# 1   31               1        113           1                 7          0
# 2   19               2        805           1                 1          1
# 3   15               1        820           1                 2          3
# 4    9               2        312           1                 1          0
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0               1                        1       0          64
# 1               1                        2       1          31
# 2               4                        3       1          62
# 3               1                        3       0          26
# 4               3                        0       1          10
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# ...

# %%
target_mtx
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
#spilte data for training and testing
x_train,x_test,y_train,y_test = train_test_split(feature_mtx,target_mtx,test_size = 0.2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape #cheak shape
# Out:
# ((1176, 30), (294, 30), (1176,), (294,))

# %%
# import RandomForestClassifier to train model
from sklearn.ensemble import RandomForestClassifier

# %%
# fit model on randomfroest
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(x_test,y_test)*100
# Out:
# 87.75510204081633

# %%
#predict from trained model 
y_pred = rf.predict(x_test)

# %%
# to check model 
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

# %%
print('accuracy',accuracy_score(y_pred,y_test)*100)
print('precision_score',precision_score(y_pred,y_test))
print('precision_score',recall_score(y_pred,y_test))
print('precision_score',f1_score(y_pred,y_test))
print('confusion_matrix')
print(confusion_matrix(y_pred,y_test))
# Out:
# accuracy 87.75510204081633
# precision_score 0.2391304347826087
# precision_score 0.9166666666666666
# precision_score 0.3793103448275862
# confusion_matrix
# [[247  35]
#  [  1  11]]

# %%
sns.heatmap(confusion_matrix(y_pred,y_test))
# Out:
# <AxesSubplot:>

# %%
import pickle

# %%
with open('model_pickle','wb') as f:
    pickle.dump(rf,f)

# %%
with open('model_pickle','rb') as f:
    mp = pickle.load(f)

# %%
x=mp.predict(x_test)

# %%
accuracy_score(y_test,x)
# Out:
# 0.8775510204081632
